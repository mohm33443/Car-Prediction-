# %%
import pandas as pd    # --> To Read File
import numpy as np     # -->  High-performance multidimensional array object
import seaborn as sns  # --> visualizations
sns.set()  # --> set the overall aesthetic style of plots (visualization)
from matplotlib import pyplot as plt   # --> visualization
# %matplotlib inline 
# --> making it easier to visualize and analyze data

# %%
df = pd.read_csv(r"D:\AI PROJECT\data.csv")
len(df)   # Number of all Rows
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df = pd.read_csv(r"D:\AI PROJECT\data.csv")
#       2 len(df)   # Number of all Rows
#
# ...

# %%
df.head()    # The first 5 Rows
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %%
len(df.columns)    # --> Number of all Columns
# Out:
# 16

# %%
df.columns     # --> Name of all Columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Fuel Type', 'Engine HP',
#        'Engine Cylinders', 'Transmission Type', 'Driven_Wheels',
#        'Number of Doors', 'Market Category', 'Vehicle Size', 'Vehicle Style',
#        'highway MPG', 'city mpg', 'Popularity', 'MSRP'],
#       dtype='object')

# %% [markdown]
# # A description for each column name

# %%
# As we see, this dataset contains multiple columns:
# make: make of a car (BMW, Toyota, and so on)
# model: model of a car
# year: year when the car was manufactured
# engine_fuel_type: type of fuel the engine needs (diesel, electric, and so on)
# engine_hp: horsepower of the engine
# engine_cylinders: number of cylinders in the engine
# transmission_type: type of transmission (automatic or manual)
# driven_wheels: front, rear, all
# number_of_doors: number of doors a car has
# market_category: luxury, crossover, and so on
# vehicle_size: compact, midsize, or large
# vehicle_style: sedan or convertible
# highway_mpg: miles per gallon (mpg) on the highway
# city_mpg: miles per gallon in the city
# popularity: number of times the car was mentioned in a Twitter stream
# msrp: manufacturer’s suggested retail price

# %%
df.info() # -->
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine Fuel Type   11911 non-null  object
#  4   Engine HP          11845 non-null  float64
#  5   Engine Cylinders   11884 non-null  float64
#  6   Transmission Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number of Doors    11908 non-null  float64
#  9   Market Category    8172 non-null   object
#  10  Vehicle Size       11914 non-null  object
#  11  Vehicle Style      11914 non-null  object
#  12  highway MPG        11914 non-null  int64
#  13  city mpg           11914 non-null  int64
#  14  Popularity         11914 non-null  int64
#  15  MSRP               11914 non-null  int64
# ...

# %%
for col in df.columns:
    print( col,':', df[col].nunique() )   # --> Number of unique value
    print(df[col].value_counts().nlargest(5))   
    # --> How many times Every unique value show (Top 5 repeated Rows )
    print('\n' + '*' * 20 + '\n')
# Out:
# Make : 48
# Make
# Chevrolet     1123
# Ford           881
# Volkswagen     809
# Toyota         746
# Dodge          626
# Name: count, dtype: int64
#
# ********************
#
# Model : 915
# Model
# Silverado 1500        156
# Tundra                140
# F-150                 126
# Sierra 1500            90
# Beetle Convertible     89
# Name: count, dtype: int64
#
# ********************
#
# Year : 28
# Year
# 2015    2170
# 2016    2157
# 2017    1668
# 2014     589
# 2012     387
# Name: count, dtype: int64
#
# ********************
#
# Engine Fuel Type : 10
# Engine Fuel Type
# regular unleaded                  7172
# premium unleaded (required)       2009
# premium unleaded (recommended)    1523
# flex-fuel (unleaded/E85)           899
# diesel                             154
# Name: count, dtype: int64
#
# ********************
#
# Engine HP : 356
# Engine HP
# 200.0    456
# 170.0    351
# 210.0    320
# 240.0    268
# 285.0    246
# Name: count, dtype: int64
#
# ...

# %% [markdown]
# ## Data Cleaning

# %%
df.info()  
# -->  information about columns & Check for missing data & Memory usage & Quick overview of the structure
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine Fuel Type   11911 non-null  object
#  4   Engine HP          11845 non-null  float64
#  5   Engine Cylinders   11884 non-null  float64
#  6   Transmission Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number of Doors    11908 non-null  float64
#  9   Market Category    8172 non-null   object
#  10  Vehicle Size       11914 non-null  object
#  11  Vehicle Style      11914 non-null  object
#  12  highway MPG        11914 non-null  int64
#  13  city mpg           11914 non-null  int64
#  14  Popularity         11914 non-null  int64
#  15  MSRP               11914 non-null  int64
# ...

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_')
# name of columns convert to lower case
string_columns = list(df.dtypes[df.dtypes == 'object'].index)
print(string_columns)
for col in string_columns:
    df[col] = df[col].str.lower().str.replace(' ', '_')
# data inside each column convert to lower case
# Out:
# ['make', 'model', 'engine_fuel_type', 'transmission_type', 'driven_wheels', 'market_category', 'vehicle_size', 'vehicle_style']

# %%
df.columns
# Out:
# Index(['make', 'model', 'year', 'engine_fuel_type', 'engine_hp',
#        'engine_cylinders', 'transmission_type', 'driven_wheels',
#        'number_of_doors', 'market_category', 'vehicle_size', 'vehicle_style',
#        'highway_mpg', 'city_mpg', 'popularity', 'msrp'],
#       dtype='object')

# %%
df.rename(columns = {'msrp': 'price'}, inplace = True)
# change name of column
# Update of original data

# %%
df.head()
# Out:
#   make       model  year             engine_fuel_type  engine_hp  \
# 0  bmw  1_series_m  2011  premium_unleaded_(required)      335.0
# 1  bmw    1_series  2011  premium_unleaded_(required)      300.0
# 2  bmw    1_series  2011  premium_unleaded_(required)      300.0
# 3  bmw    1_series  2011  premium_unleaded_(required)      230.0
# 4  bmw    1_series  2011  premium_unleaded_(required)      230.0
#
#    engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# 0               6.0            manual  rear_wheel_drive              2.0
# 1               6.0            manual  rear_wheel_drive              2.0
# 2               6.0            manual  rear_wheel_drive              2.0
# 3               6.0            manual  rear_wheel_drive              2.0
# 4               6.0            manual  rear_wheel_drive              2.0
#
#                          market_category vehicle_size vehicle_style  \
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
pd.options.display.float_format = '{:,.2f}'.format
# --> only two digits after the decimal point. 
df.describe()
# statistical information for numerical columns in data
# Out:
#            year  engine_hp  engine_cylinders  number_of_doors  highway_mpg  \
# count 11,914.00  11,845.00         11,884.00        11,908.00    11,914.00
# mean   2,010.38     249.39              5.63             3.44        26.64
# std        7.58     109.19              1.78             0.88         8.86
# min    1,990.00      55.00              0.00             2.00        12.00
# 25%    2,007.00     170.00              4.00             2.00        22.00
# 50%    2,015.00     227.00              6.00             4.00        26.00
# 75%    2,016.00     300.00              6.00             4.00        30.00
# max    2,017.00   1,001.00             16.00             4.00       354.00
#
#        city_mpg  popularity        price
# count 11,914.00   11,914.00    11,914.00
# mean      19.73    1,554.91    40,594.74
# std        8.99    1,441.86    60,109.10
# min        7.00        2.00     2,000.00
# 25%       16.00      549.00    21,000.00
# 50%       18.00    1,385.00    29,995.00
# ...

# %%
df.describe(include=['O'])
# --> object column
# Out:
#              make           model  engine_fuel_type transmission_type  \
# count       11914           11914             11911             11914
# unique         48             914                10                 5
# top     chevrolet  silverado_1500  regular_unleaded         automatic
# freq         1123             156              7172              8266
#
#             driven_wheels market_category vehicle_size vehicle_style
# count               11914            8172        11914         11914
# unique                  4              71            3            16
# top     front_wheel_drive       crossover      compact         sedan
# freq                 4787            1110         4764          3048

# %% [markdown]
# # Target variable analysis (price)

# %%
plt.figure(figsize=(15, 7))

sns.histplot(df.price, bins=40)
plt.ylabel('Frequency')
plt.xlabel('Price')
plt.title('Distribution of prices')

plt.show()
# histogram

# %%
plt.figure(figsize=(6, 4))

sns.histplot(df.price[df.price < 100000], bins=40)
plt.ylabel('Frequency')
plt.xlabel('Price')
plt.title('Distribution of prices')

plt.show()

# %%
df['log_price'] = np.log1p(df.price)

plt.figure(figsize=(6, 4))

sns.histplot(df.log_price, bins=40)
plt.ylabel('Frequency')
plt.xlabel('Log(Price + 1)')
plt.title('Distribution of prices after log tranformation')

plt.show()

# %%
df.price.skew()
# before log tranformation
# Out:
# 11.771987129334972

# %%
df.log_price.skew()
# after log tranformation
# Out:
# -0.9178678067039072

# %% [markdown]
# # Check missing values

# %%
df.isnull().sum()
# number of null value ( true or false )
# Out:
# make                    0
# model                   0
# year                    0
# engine_fuel_type        3
# engine_hp              69
# engine_cylinders       30
# transmission_type       0
# driven_wheels           0
# number_of_doors         6
# market_category      3742
# vehicle_size            0
# vehicle_style           0
# highway_mpg             0
# city_mpg                0
# popularity              0
# price                   0
# log_price               0
# dtype: int64

# %% [markdown]
# # Check categorical columns ( string )

# %%
string_columns
# Out:
# ['make',
#  'model',
#  'engine_fuel_type',
#  'transmission_type',
#  'driven_wheels',
#  'market_category',
#  'vehicle_size',
#  'vehicle_style']

# %% [markdown]
# ## What's the average price of BMW cars in the dataset ?

# %%
df.make.value_counts()
# Out:
# make
# chevrolet        1123
# ford              881
# volkswagen        809
# toyota            746
# dodge             626
# nissan            558
# gmc               515
# honda             449
# mazda             423
# cadillac          397
# mercedes-benz     353
# suzuki            351
# bmw               334
# infiniti          330
# audi              328
# hyundai           303
# volvo             281
# subaru            256
# acura             252
# kia               231
# mitsubishi        213
# lexus             202
# buick             196
# chrysler          187
# pontiac           186
# lincoln           164
# oldsmobile        150
# land_rover        143
# porsche           136
# saab              111
# aston_martin       93
# plymouth           82
# bentley            74
# ferrari            69
# fiat               62
# scion              60
# maserati           58
# lamborghini        52
# rolls-royce        31
# lotus              29
# tesla              18
# ...

# %%
df.groupby('make').mean(numeric_only=True)
# Out:
#                   year  engine_hp  engine_cylinders  number_of_doors  \
# make
# acura         2,010.06     244.80              5.33             3.62
# alfa_romeo    2,015.40     237.00              4.00             2.00
# aston_martin  2,013.02     484.32             10.62             2.15
# audi          2,012.23     277.70              5.56             3.47
# bentley       2,011.70     533.85              9.73             2.68
# bmw           2,014.35     326.91              5.96             3.16
# bugatti       2,008.33   1,001.00             16.00             2.00
# buick         2,010.01     219.24              5.32             3.84
# cadillac      2,013.15     332.31              6.43             3.60
# chevrolet     2,010.09     246.97              5.91             3.38
# chrysler      2,008.46     229.14              5.59             3.63
# dodge         2,005.44     244.42              6.26             3.21
# ...

# %%
df.groupby('make').mean(numeric_only=True)['price']['bmw']
# Out:
# 61546.76347305389

# %% [markdown]
# ## Compare the average price for cars before / after year 2015

# %%
df[df['year'] >= 2015]
# Out:
#        make       model  year                engine_fuel_type  engine_hp  \
# 32     fiat  124_spider  2017  premium_unleaded_(recommended)     160.00
# 33     fiat  124_spider  2017  premium_unleaded_(recommended)     160.00
# 34     fiat  124_spider  2017  premium_unleaded_(recommended)     160.00
# 41      bmw    2_series  2016     premium_unleaded_(required)     240.00
# 42      bmw    2_series  2016     premium_unleaded_(required)     240.00
# ...     ...         ...   ...                             ...        ...
# 11898   bmw          z4  2015     premium_unleaded_(required)     300.00
# 11899   bmw          z4  2015     premium_unleaded_(required)     335.00
# 11900   bmw          z4  2016     premium_unleaded_(required)     300.00
# 11901   bmw          z4  2016     premium_unleaded_(required)     240.00
# 11902   bmw          z4  2016     premium_unleaded_(required)     335.00
#
#        engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# ...

# %%
df.price.mean()
# Out:
# 40594.737032063116

# %%
df[df['year'] >= 2015]['price'].mean()
# Out:
# 45667.156463719766

# %%
df[df['year'] < 2015]['price'].mean()
# Out:
# 35457.18770062511

# %% [markdown]
# # Validation framework

# %%
np.random.seed(2)     
# --> Fixes the random seed to make sure that the results are reproducible
n = len(df)

n_val = int(0.2 * n)    # --> 20%
n_test = int(0.2 * n)   # --> 20%
n_train = n - (n_val + n_test)    # --> 60%

print('No. of rows for training : ', n_train)
print('No. of rows for validation : ', n_val)
print('No. of rows for testing : ', n_test)
# Out:
# No. of rows for training :  7150
# No. of rows for validation :  2382
# No. of rows for testing :  2382

# %%
idx = np.arange(n)
print(idx)

np.random.shuffle(idx)
print(idx)
# --> change the order of indexes of rows
# Out:
# [    0     1     2 ... 11911 11912 11913]
# [2735 6720 5878 ... 6637 2575 7336]

# %%
df_shuffled = df.iloc[idx]
print(df.index)
print(df_shuffled.index)
# Out:
# RangeIndex(start=0, stop=11914, step=1)
# Index([ 2735,  6720,  5878, 11190,  4554,  8001,  2882,   649,   616,  4459,
#        ...
#         6751,   433,  4770, 11527,  1099,  2514, 11798,  6637,  2575,  7336],
#       dtype='int64', length=11914)

# %%
df_shuffled
# Out:
#              make         model  year          engine_fuel_type  engine_hp  \
# 2735    chevrolet        cobalt  2008          regular_unleaded     148.00
# 6720       toyota        matrix  2012          regular_unleaded     132.00
# 5878       subaru       impreza  2016          regular_unleaded     148.00
# 11190  volkswagen       vanagon  1991          regular_unleaded      90.00
# 4554         ford         f-150  2017  flex-fuel_(unleaded/e85)     385.00
# ...           ...           ...   ...                       ...        ...
# 2514    chevrolet     chevy_van  1998          regular_unleaded     200.00
# 11798      subaru  xv_crosstrek  2014          regular_unleaded     160.00
# 6637        dodge        magnum  2006          regular_unleaded     250.00
# 2575        honda         civic  2016          regular_unleaded     174.00
# 7336       subaru       outback  2015          regular_unleaded     256.00
#
# ...

# %%
df
# Out:
#           make       model  year                engine_fuel_type  engine_hp  \
# 0          bmw  1_series_m  2011     premium_unleaded_(required)     335.00
# 1          bmw    1_series  2011     premium_unleaded_(required)     300.00
# 2          bmw    1_series  2011     premium_unleaded_(required)     300.00
# 3          bmw    1_series  2011     premium_unleaded_(required)     230.00
# 4          bmw    1_series  2011     premium_unleaded_(required)     230.00
# ...        ...         ...   ...                             ...        ...
# 11909    acura         zdx  2012     premium_unleaded_(required)     300.00
# 11910    acura         zdx  2012     premium_unleaded_(required)     300.00
# 11911    acura         zdx  2012     premium_unleaded_(required)     300.00
# 11912    acura         zdx  2013  premium_unleaded_(recommended)     300.00
# 11913  lincoln      zephyr  2006                regular_unleaded     221.00
#
# ...

# %%
df_train = df_shuffled.iloc[:n_train].copy()  # --> 60%  [0:7150]
df_val = df_shuffled.iloc[n_train:n_train+n_val].copy()   # --> 20%  [7150:9532]
df_test = df_shuffled.iloc[n_train+n_val:].copy()   # --> 20%  [9432:11913]

# %%
df_train.shape
# Out:
# (7150, 17)

# %%
df_val.shape
# Out:
# (2382, 17)

# %%
df_test.shape
# Out:
# (2382, 17)

# %%
y_train = df_train.log_price.values
y_val = df_val.log_price.values
y_test = df_test.log_price.values

# %% [markdown]
# # Baseline solution

# %%
base = ['engine_hp', 'engine_cylinders', 'highway_mpg', 'city_mpg', 'popularity']   
# Numerical value only
#base = ['engine_hp', 'engine_cylinders'] 
# missing values

# %%
df[base]
# Out:
#        engine_hp  engine_cylinders  highway_mpg  city_mpg  popularity
# 0         335.00              6.00           26        19        3916
# 1         300.00              6.00           28        19        3916
# 2         300.00              6.00           28        20        3916
# 3         230.00              6.00           28        18        3916
# 4         230.00              6.00           28        18        3916
# ...          ...               ...          ...       ...         ...
# 11909     300.00              6.00           23        16         204
# 11910     300.00              6.00           23        16         204
# 11911     300.00              6.00           23        16         204
# 11912     300.00              6.00           23        16         204
# 11913     221.00              6.00           26        17          61
#
# [11914 rows x 5 columns]

# %%
df[base].isnull().sum()
# Out:
# engine_hp           69
# engine_cylinders    30
# highway_mpg          0
# city_mpg             0
# popularity           0
# dtype: int64

# %% [markdown]
# # Handling Missing Values

# %%
def prepare_X(df):
    df_num = df[base]
    df_num = df_num.fillna(df_num.mean())
    X = df_num.values
    return X

# %% [markdown]
# # Linear Regression

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

image_path = 'D:\AI PROJECT\linear-regression.png'

img = mpimg.imread(image_path)

plt.imshow(img)
plt.axis('off') 
plt.show()

# %%
df_train.corr(numeric_only=True)
# Out:
#                   year  engine_hp  engine_cylinders  number_of_doors  \
# year              1.00       0.36             -0.04             0.26
# engine_hp         0.36       1.00              0.78            -0.10
# engine_cylinders -0.04       0.78              1.00            -0.14
# number_of_doors   0.26      -0.10             -0.14             1.00
# highway_mpg       0.25      -0.39             -0.60             0.11
# city_mpg          0.20      -0.44             -0.60             0.12
# popularity        0.08       0.04              0.04            -0.05
# price             0.22       0.65              0.51            -0.12
# log_price         0.77       0.68              0.35             0.11
#
#                   highway_mpg  city_mpg  popularity  price  log_price
# year                     0.25      0.20        0.08   0.22       0.77
# engine_hp               -0.39     -0.44        0.04   0.65       0.68
# ...

# %%
plt.figure(figsize=(15,8))
_=sns.heatmap(df_train.corr(numeric_only=True), annot = True)
# visualization 
# --> 1 strong correlation
# --> 0 week correlation

# %%
def linear_regression(xi):
    n =len(xi)                
    pred = w0                

    for j in range(n):
        pred += w[j]*xi[j]     

    return pred

# %% [markdown]
# # Using Normal Equation

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

image_path = r'D:\AI PROJECT\normal-equation.jpg'

img = mpimg.imread(image_path)

plt.imshow(img)
plt.axis('off') 
plt.show()

# %% [markdown]
# # Gradient Descent

# %%
def train_linear_regression(X, y):
    ones = np.ones(X.shape[0])
    X = np.column_stack([ones, X]) # --> ones & other featuters

    XTX = X.T.dot(X)
    XTX_inv = np.linalg.inv(XTX)
    w = XTX_inv.dot(X.T).dot(y)

    return w[0], w[1:]

# %%
X_train = prepare_X(df_train)  # numpy array
w_0, w = train_linear_regression(X_train, y_train)
y_pred = w_0 + X_train.dot(w)

# %%
sns.histplot(y_train, label='target')
sns.histplot(y_pred, label='prediction', color='red')

plt.legend()

plt.ylabel('Frequency')
plt.xlabel('Log(Price + 1)')
plt.title('Predictions vs actual distribution')

plt.show()

# %% [markdown]
# # Model Evaluation

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

image_path = 'D:\AI PROJECT\model-evaluation.png'

img = mpimg.imread(image_path)

plt.imshow(img)
plt.axis('off') 
plt.show()

# %%
def rmse(y, y_pred):
    error = y_pred - y
    mse = (error ** 2).mean()
    return np.sqrt(mse)
# array

# %%
rmse(y_train, y_pred)
# Out:
# 0.7574439819012008

# %%
X_val = prepare_X(df_val)
y_pred = w_0 + X_val.dot(w)

# %%
rmse(y_val, y_pred)
# Out:
# 0.7502502346381926

# %% [markdown]
# # Simple Feature Engineering

# %%
base
# numurical values
# Out:
# ['engine_hp', 'engine_cylinders', 'highway_mpg', 'city_mpg', 'popularity']

# %%
sorted(df.year.unique())
# Out:
# [1990,
#  1991,
#  1992,
#  1993,
#  1994,
#  1995,
#  1996,
#  1997,
#  1998,
#  1999,
#  2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016,
#  2017]

# %%
def prepare_X(df):
    df = df.copy()
    features = base.copy()

    df['age'] = 2017 - df.year  # new column
    features.append('age')

    df_num = df[features]
    df_num = df_num.fillna(df_num.mean())
    X = df_num.values
    return X

# %%
X_train = prepare_X(df_train)
w_0, w = train_linear_regression(X_train, y_train)
y_pred = w_0 + X_train.dot(w)
print('Train RMSE: ', rmse(y_train, y_pred))

X_val = prepare_X(df_val)
y_pred = w_0 + X_val.dot(w)
print('Validation RMSE: ', rmse(y_val, y_pred))
# Out:
# Train RMSE:  0.5117454503079417
# Validation RMSE:  0.5070033906013027

# %%
plt.figure(figsize=(6, 4))


sns.histplot(y_val, label='target', color='blue', alpha=0.6, bins=40)
sns.histplot(y_pred, label='prediction', color='green', alpha=0.8, bins=40)

plt.legend()

plt.ylabel('Frequency')
plt.xlabel('Log(Price + 1)')
plt.title('Predictions vs actual distribution')

plt.show()

# %% [markdown]
# # Handling Categorical Variables

# %%
df.number_of_doors.value_counts()
# Out:
# number_of_doors
# 4.00    8353
# 2.00    3160
# 3.00     395
# Name: count, dtype: int64

# %%
df['make'].value_counts().head()
# Out:
# make
# chevrolet     1123
# ford           881
# volkswagen     809
# toyota         746
# dodge          626
# Name: count, dtype: int64

# %%
def prepare_X(df):
    df = df.copy()
    features = base.copy()

    df['age'] = 2017 - df.year
    features.append('age')

    for v in [2, 3, 4]:
        feature = 'num_doors_%s' % v  # 2 or 3 or 4
        df[feature] = (df['number_of_doors'] == v).astype(int)  # 0 or 1
        features.append(feature)

    for v in ['chevrolet', 'ford', 'volkswagen', 'toyota', 'dodge']:
        feature = 'is_make_%s' % v
        df[feature] = (df['make'] == v).astype(int) # 0 or 1
        features.append(feature)

    df_num = df[features]
    df_num = df_num.fillna(df_num.mean())
    X = df_num.values
    return X

# %%
X_train = prepare_X(df_train)
w_0, w = train_linear_regression(X_train, y_train)

y_pred = w_0 + X_train.dot(w)
print('train:', rmse(y_train, y_pred))

X_val = prepare_X(df_val)
y_pred = w_0 + X_val.dot(w)
print('validation:', rmse(y_val, y_pred))
# Out:
# train: 0.5010764007201611
# validation: 0.4982643557276847

# %% [markdown]
# # engine_fuel_type

# %%
df['engine_fuel_type'].value_counts()
# Out:
# engine_fuel_type
# regular_unleaded                                7172
# premium_unleaded_(required)                     2009
# premium_unleaded_(recommended)                  1523
# flex-fuel_(unleaded/e85)                         899
# diesel                                           154
# electric                                          66
# flex-fuel_(premium_unleaded_required/e85)         54
# flex-fuel_(premium_unleaded_recommended/e85)      26
# flex-fuel_(unleaded/natural_gas)                   6
# natural_gas                                        2
# Name: count, dtype: int64

# %%
def prepare_X(df):
    df = df.copy()
    features = base.copy()

    df['age'] = 2017 - df.year
    features.append('age')

    for v in [2, 3, 4]:
        feature = 'num_doors_%s' % v
        df[feature] = (df['number_of_doors'] == v).astype(int)
        features.append(feature)

    for v in ['chevrolet', 'ford', 'volkswagen', 'toyota', 'dodge']:
        feature = 'is_make_%s' % v
        df[feature] = (df['make'] == v).astype(int)
        features.append(feature)

    for v in ['regular_unleaded', 'premium_unleaded_(required)',
              'premium_unleaded_(recommended)', 'flex-fuel_(unleaded/e85)']:
        feature = 'is_type_%s' % v
        df[feature] = (df['engine_fuel_type'] == v).astype(int)
        features.append(feature)

    df_num = df[features]
    df_num = df_num.fillna(0)
    X = df_num.values
    return X

# %%
X_train = prepare_X(df_train)
w_0, w = train_linear_regression(X_train, y_train)

y_pred = w_0 + X_train.dot(w)
print('train:', rmse(y_train, y_pred))

X_val = prepare_X(df_val)
y_pred = w_0 + X_val.dot(w)
print('validation:', rmse(y_val, y_pred))
# Out:
# train: 0.4788482615078598
# validation: 0.4748256737227088

# %% [markdown]
# # transmission_type

# %%
df['transmission_type'].value_counts()
# Out:
# transmission_type
# automatic           8266
# manual              2935
# automated_manual     626
# direct_drive          68
# unknown               19
# Name: count, dtype: int64

# %% [markdown]
# # driven_wheels

# %%
df['driven_wheels'].value_counts()
# Out:
# driven_wheels
# front_wheel_drive    4787
# rear_wheel_drive     3371
# all_wheel_drive      2353
# four_wheel_drive     1403
# Name: count, dtype: int64

# %% [markdown]
# # market_category

# %%
df['market_category'].value_counts().head(5)
# Out:
# market_category
# crossover             1110
# flex_fuel              872
# luxury                 855
# luxury,performance     673
# hatchback              641
# Name: count, dtype: int64

# %% [markdown]
# # vehicle_style

# %%
df['vehicle_style'].value_counts().head(5)
# Out:
# vehicle_style
# sedan            3048
# 4dr_suv          2488
# coupe            1211
# convertible       793
# 4dr_hatchback     702
# Name: count, dtype: int64

# %%
def prepare_X(df):
    df = df.copy()
    features = base.copy()

    df['age'] = 2017 - df.year
    features.append('age')

    for v in [2, 3, 4]:
        feature = 'num_doors_%s' % v
        df[feature] = (df['number_of_doors'] == v).astype(int)
        features.append(feature)

    for v in ['chevrolet', 'ford', 'volkswagen', 'toyota', 'dodge']:
        feature = 'is_make_%s' % v
        df[feature] = (df['make'] == v).astype(int)
        features.append(feature)

    for v in ['regular_unleaded', 'premium_unleaded_(required)',
              'premium_unleaded_(recommended)', 'flex-fuel_(unleaded/e85)']:
        feature = 'is_type_%s' % v
        df[feature] = (df['engine_fuel_type'] == v).astype(int)
        features.append(feature)

    for v in ['automatic', 'manual', 'automated_manual']:
        feature = 'is_transmission_%s' % v
        df[feature] = (df['transmission_type'] == v).astype(int)
        features.append(feature)

    df_num = df[features]
    df_num = df_num.fillna(df_num.mean())
    X = df_num.values
    return X

# %%
X_train = prepare_X(df_train)
w_0, w = train_linear_regression(X_train, y_train)

y_pred = w_0 + X_train.dot(w)
print('train:', rmse(y_train, y_pred))

X_val = prepare_X(df_val)
y_pred = w_0 + X_val.dot(w)
print('validation:', rmse(y_val, y_pred))
# Out:
# train: 0.47227213583716016
# validation: 0.46536943866904223

# %%
def prepare_X(df):
    df = df.copy()
    features = base.copy()

    df['age'] = 2017 - df.year
    features.append('age')

    for v in [2, 3, 4]:
        feature = 'num_doors_%s' % v
        df[feature] = (df['number_of_doors'] == v).astype(int)
        features.append(feature)

    for v in ['chevrolet', 'ford', 'volkswagen', 'toyota', 'dodge']:
        feature = 'is_make_%s' % v
        df[feature] = (df['make'] == v).astype(int)
        features.append(feature)

    for v in ['regular_unleaded', 'premium_unleaded_(required)',
              'premium_unleaded_(recommended)', 'flex-fuel_(unleaded/e85)']:
        feature = 'is_type_%s' % v
        df[feature] = (df['engine_fuel_type'] == v).astype(int)
        features.append(feature)

    for v in ['automatic', 'manual', 'automated_manual']:
        feature = 'is_transmission_%s' % v
        df[feature] = (df['transmission_type'] == v).astype(int)
        features.append(feature)

    for v in ['front_wheel_drive', 'rear_wheel_drive', 'all_wheel_drive', 'four_wheel_drive']:
        feature = 'is_driven_wheels_%s' % v
        df[feature] = (df['driven_wheels'] == v).astype(int)
        features.append(feature)

    for v in ['crossover', 'flex_fuel', 'luxury', 'luxury,performance', 'hatchback']:
        feature = 'is_mc_%s' % v
        df[feature] = (df['market_category'] == v).astype(int)
        features.append(feature)

    for v in ['compact', 'midsize', 'large']:
        feature = 'is_size_%s' % v
        df[feature] = (df['vehicle_size'] == v).astype(int)
        features.append(feature)

    for v in ['sedan', '4dr_suv', 'coupe', 'convertible', '4dr_hatchback']:
        feature = 'is_style_%s' % v
        df[feature] = (df['vehicle_style'] == v).astype(int)
        features.append(feature)

    df_num = df[features]
    df_num = df_num.fillna(df_num.mean())
    X = df_num.values
    return X

# %%
X_train = prepare_X(df_train)
w_0, w = train_linear_regression(X_train, y_train)

y_pred = w_0 + X_train.dot(w)
print('train:', rmse(y_train, y_pred))

X_val = prepare_X(df_val)
y_pred = w_0 + X_val.dot(w)
print('validation:', rmse(y_val, y_pred))
# Out:
# train: 228.31954162041066
# validation: 108.39856394660417

# %%
w.astype(int)
# Out:
# C:\Users\ag\AppData\Local\Temp\ipykernel_18320\1114629410.py:1: RuntimeWarning: invalid value encountered in cast
#   w.astype(int)
# array([          0,          54,          12,           8,           0,
#                  8,        7273,        7363,        7312,          -8,
#                -16,          76,          -9,           6,         194,
#                140,         172,         216,         531,         538,
#                497, -2147483648, -2147483648, -2147483648, -2147483648,
#                 46,         -23,          -2,         -15,         -35,
#               -169,        -171,        -196,           0,           0,
#                  0,           0,           0])

# %% [markdown]
# # Regularization

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

image_path = r'D:\AI PROJECT\regularization.png'

img = mpimg.imread(image_path)

plt.imshow(img)
plt.axis('off') 
plt.show()

# %%
def train_linear_regression_reg(X, y, r=0.0):
    ones = np.ones(X.shape[0])
    X = np.column_stack([ones, X])

    XTX = X.T.dot(X)
    reg = r * np.eye(XTX.shape[0])
    XTX = XTX + reg

    XTX_inv = np.linalg.inv(XTX)
    w = XTX_inv.dot(X.T).dot(y)

    return w[0], w[1:]

# %%
X_train = prepare_X(df_train)

# %%
for r in [0, 0.001, 0.01, 0.1, 1, 10]:
    w_0, w = train_linear_regression_reg(X_train, y_train, r=r)
    print('%5s, %.2f, %.2f, %.2f' % (r, w_0, w[13], w[21]))
# Out:
#     0, 1144088102144513.50, 6.49, -1144088102153391.00
# 0.001, 6.96, -0.10, 1.76
#  0.01, 6.95, -0.10, 1.76
#   0.1, 6.82, -0.10, 1.73
#     1, 6.04, -0.10, 1.52
#    10, 4.32, -0.09, 1.07

# %%
X_train = prepare_X(df_train)
w_0, w = train_linear_regression_reg(X_train, y_train, r=0)

y_pred = w_0 + X_train.dot(w)
print('train', rmse(y_train, y_pred))

X_val = prepare_X(df_val)
y_pred = w_0 + X_val.dot(w)
print('val', rmse(y_val, y_pred))
# Out:
# train 228.31954162041066
# val 108.39856394660417

# %%
X_train = prepare_X(df_train)
w_0, w = train_linear_regression_reg(X_train, y_train, r=0.01)

y_pred = w_0 + X_train.dot(w)
print('train', rmse(y_train, y_pred))

X_val = prepare_X(df_val)
y_pred = w_0 + X_val.dot(w)
print('val', rmse(y_val, y_pred))
# Out:
# train 0.4623435461978201
# val 0.45751588645925845

# %%
X_train = prepare_X(df_train)
X_val = prepare_X(df_val)

for r in [0.000001, 0.0001, 0.001, 0.01, 0.1, 1, 5, 10]:
    w_0, w = train_linear_regression_reg(X_train, y_train, r=r)
    y_pred = w_0 + X_val.dot(w)
    print('%6s' %r, rmse(y_val, y_pred))
# Out:
#  1e-06 0.4575030410102276
# 0.0001 0.45750331653769405
#  0.001 0.4575044546317788
#   0.01 0.45751588645925845
#    0.1 0.45763258277504987
#      1 0.45890469947596735
#      5 0.46450155470599086
#     10 0.4707849371629994

# %%
X_train = prepare_X(df_train)
w_0, w = train_linear_regression_reg(X_train, y_train, r=0.01)

X_val = prepare_X(df_val)
y_pred = w_0 + X_val.dot(w)
print('validation:', rmse(y_val, y_pred))

X_test = prepare_X(df_test)
y_pred = w_0 + X_test.dot(w)
print('test:', rmse(y_test, y_pred))
# Out:
# validation: 0.45751588645925845
# test: 0.45460022121092664

# %% [markdown]
# # Finallllllllly  Using the model

# %%
i = 100
ad = df_test.iloc[i].to_dict()
ad
# Out:
# {'make': 'chevrolet',
#  'model': 'colorado',
#  'year': 2012,
#  'engine_fuel_type': 'regular_unleaded',
#  'engine_hp': 185.0,
#  'engine_cylinders': 4.0,
#  'transmission_type': 'automatic',
#  'driven_wheels': 'rear_wheel_drive',
#  'number_of_doors': 2.0,
#  'market_category': nan,
#  'vehicle_size': 'compact',
#  'vehicle_style': 'regular_cab_pickup',
#  'highway_mpg': 25,
#  'city_mpg': 18,
#  'popularity': 1385,
#  'price': 20370,
#  'log_price': 9.921867599817558}

# %%
X_test = prepare_X(pd.DataFrame([ad]))
y_pred = w_0 + X_test.dot(w)
suggestion = np.expm1(y_pred)
suggestion
# Out:
# array([17122.11353284])
